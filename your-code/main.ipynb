# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1

fig, ax = plt.subplots(figsize = (8,8))

ax.set_title('Representation of Y and Z')

ax.plot(x, y, label = 'y= x*2')
ax.plot(x, z, label = 'z= x**2')
ax.legend()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

fig1, axes1 = plt.subplots(1,2)
axes1[0].set_title("Representation of Y")
axes1[1].set_title("Representation of Z")

axes1[0].plot(x, y)
axes1[1].plot(x, z)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig1, axes1 = plt.subplots(1,2, figsize = (12,6))
axes1[0].set_title("Representation of Y", fontweight = 'bold')
axes1[1].set_title("Representation of Z", fontweight = 'bold')

axes1[0].plot(x, y, label = 'y= x*2', c= 'gold')
axes1[1].plot(x, z, label = 'z = x**2')

for ax in axes1:
    ax.legend()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
import math

# %%
# 2 axes. in the right one normal scale, left one logarithmic scale 

y1 = x**2
y2 = math.e**x

# %%
fig2, axes2 = plt.subplots(1,2, figsize = (12,6))

#linear scale
axes2[0].set_title('Linear representation of Y1 and Y2')

axes2[0].set_yscale('linear')
axes2[0].plot(x, y1)
axes2[0].plot(x, y2)


#logarithmic scale 
axes2[1].set_title('Logarithmic representation of Y1 and Y2')

axes2[1].set_yscale('log')
axes2[1].plot(x, y1)
axes2[1].plot(x, y2)

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
fig2, axes2 = plt.subplots(1,2, figsize = (12,6))

#linear scale
axes2[0].set_title('Linear representation of Y1 and Y2')

axes2[0].set_yscale('linear')
axes2[0].plot(x, y1, label = 'y1 = x**2')
axes2[0].plot(x, y2, label = 'y2 = e**x')

axes2[0].legend()

#logarithmic scale 
axes2[1].set_title('Logarithmic representation of Y1 and Y2')

axes2[1].set_yscale('log')
axes2[1].plot(x, y1, label = 'y1 = x**2')
axes2[1].plot(x, y2, label = 'y2 = e**x')

axes2[1].legend()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('/Users/Sergio/Desktop/IRONHACK/LABS/week5/Day2/Datasets as CSV/Fitbit2.csv')

# %%
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED

median_steps_month = fitbit.groupby(['Months_encoded'])['Steps'].median().reset_index()


fig3, ax3 = plt.subplots(figsize = (12,4))


ax3.set_title('Median steps by month', fontsize= 16)
ax3.plot('Months_encoded', 'Steps', data = median_steps_month)


# MEDIAN STEPS BY WORK_OR_WEEKEND
fitbit.loc[fitbit['Work_or_Weekend'] == 0, 'Work_or_Weekend'] = 'Weekend'
fitbit.loc[fitbit['Work_or_Weekend'] == 1, 'Work_or_Weekend'] = 'Workday'

median_steps_day = fitbit.groupby(['Work_or_Weekend'])['Steps'].median().reset_index()

fig4, ax4 = plt.subplots(figsize = (12,4))


ax4.set_title('Median steps by type of day', fontsize= 16)
ax4.barh('Work_or_Weekend', 'Steps', data = median_steps_day)

fig3.savefig("figures.png")

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
features = ["Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"]

i=0

fig5, axes5 = plt.subplots(1,3, figsize = (15,5))


for feature in features:
    axes5[i].scatter(fitbit[feature], fitbit['Steps'], label = features)
    axes5[i].set_title(feature)
    i+=1

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('/Users/Sergio/Desktop/IRONHACK/LABS/week5/Day2/Datasets as CSV/titanic.csv')

# %%
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include=['int64','float64'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include=['object'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
titanic['Age'].hist(color = 'dodgerblue', grid=False, figsize=(12,6), zorder=2, rwidth=0.9)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
age_bins = [10, 20, 50]

i=0

fig6, axes6 = plt.subplots(1,3, figsize = (12,6))
fig6.suptitle('Distribution of variable Age in bins', fontsize = 18)

for age in age_bins:
    axes6[i].hist('Age',bins = age, label = 'Age',rwidth=0.9, data = titanic)
    axes6[i].set_title(age)
    i+=1

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The more bins displayed, the better represents the distribution of the 'Age' variable and the more it looks like a normal distribution.

"""
# Out:
# "\nThe more bins displayed, the better represents the distribution of the 'Age' variable and the more it looks like a normal distribution.\n\n"

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.set_palette('colorblind')

# %%
fig7, ax7 = plt.subplots(figsize= (12,6))

sns.histplot(x = 'Age', ax = ax7, data = titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %%
gender_titanic = titanic['Gender'].value_counts()

# %%
gender_titanic
# Out:
# male      843
# female    466
# Name: Gender, dtype: int64

# %%
# Method 1 - matplotlib

fig8, ax8 = plt.subplots(figsize = (6,6))

ax8.set_title('Titanic gender ratio', fontweight = 'bold')
ax8.bar(x = gender_titanic.index, height= gender_titanic, color =('blue', 'gold'))
# Out:
# <BarContainer object of 2 artists>

# %%
# Method 2 - seaborn
fig9, ax9 = plt.subplots(figsize = (6,6))

ax9.set_title('Titanic gender ratio', fontweight = 'bold')

sns.barplot(x = gender_titanic.index, y = gender_titanic, ax= ax9)
# Out:
# <AxesSubplot:title={'center':'Titanic gender ratio'}, ylabel='Gender'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
titanic_pclass = titanic['Pclass'].value_counts()[[1,2,3]]

# %%
fig9, ax9 = plt.subplots(figsize = (6,6))

titanic_pclass = titanic['Pclass'].value_counts()[[1,2,3]]
titanic_pclass.rename(index= {1: 'First', 2: 'Second', 3: 'Third'}, inplace = True)

ax9.set_title('Passengers by class', fontweight = 'bold')
ax9.bar(x = titanic_pclass.index, height= titanic_pclass)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
fig10, ax10 = plt.subplots(figsize = (12,6))

ax10.set_title('Age of Titanic passengers', fontweight = 'bold')
sns.set_theme(style="white")
sns.scatterplot(data = titanic['Age'])
# Out:
# <AxesSubplot:title={'center':'Age of Titanic passengers'}, ylabel='Age'>

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
We can see that the most part of the passengers ages range between 20 and 40 years
"""
# Out:
# '\nWe can see that the most part of the passengers ages range between 20 and 40 years\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.jointplot(data = titanic['Age'])

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Confirms the results of scatter plot set before where the most common ages for passengers range between 20 and 40 years.
"""
# Out:
# '\nConfirms the results of scatter plot set before where the most common ages for passengers range between 20 and 40 years.\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
fig11, ax11 = plt.subplots(figsize = (6,6))

ax11.scatter(x= 'Age', y= 'Fare', data= titanic)

# %%
# Method 2 - seaborn
sns.relplot(x="Age", y="Fare", data = titanic)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
sns.heatmap(titanic.corr(), annot = True, vmin=-1, vmax=1, center= 0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
The fare prices and the passenger class.
"""
# Out:
# '\nThe fare prices and the passenger class.\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.catplot(data = titanic, x = 'Pclass', y= 'Age', kind = 'violin')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.catplot(data = titanic, x = 'Gender', y= 'Age', kind = 'violin')
